# %%
import pandas as pd
from spotify_api import get_playlist_info
from sklearn.metrics.pairwise import cosine_similarity
from feature_engineering import feature_engineering

# %%
def generate_playlist_feature(complete_feature_set, playlist_df):
    # Find song features in the playlist
    complete_feature_set_playlist = complete_feature_set[complete_feature_set['track_uri'].isin(playlist_df['track_uri'].values)]
    # Find all non-playlist song features
    complete_feature_set_nonplaylist = complete_feature_set[~complete_feature_set['track_uri'].isin(playlist_df['track_uri'].values)]
    complete_feature_set_playlist_final = complete_feature_set_playlist.drop(columns = "track_uri")
    return complete_feature_set_playlist_final.sum(axis = 0), complete_feature_set_nonplaylist

# %%
def generate_playlist_recos(df, features, nonplaylist_features, n):
    non_playlist_df = df[df['track_uri'].isin(nonplaylist_features['track_uri'].values)]
    non_playlist_df['sim'] = cosine_similarity(nonplaylist_features.drop('track_uri', axis=1).values, features.values.reshape(1, -1))[:, 0]
    non_playlist_df_top_40 = non_playlist_df.sort_values('sim', ascending=False).head(n)
    return non_playlist_df_top_40

# %%
def recommendations(input_link, n):
    input_df = get_playlist_info(input_link)
    song_dataset = pd.read_csv('song_dataset.csv')
    recommendation_set = pd.concat([song_dataset, input_df]).to_csv('recommendation_set.csv', index=False)
    feature_df, all_songs = feature_engineering()
    complete_feature_set_playlist_vector, complete_feature_set_nonplaylist = generate_playlist_feature(feature_df, input_df)
    answer = generate_playlist_recos(all_songs, complete_feature_set_playlist_vector, complete_feature_set_nonplaylist, n)[['track_name', 'artist_name', 'album_name']]
    answer.to_csv('answer.csv', index=False)
    return answer

# %%
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_38360\2860551503.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_playlist_df['sim'] = cosine_similarity(nonplaylist_features.drop('track_uri', axis=1).values, features.values.reshape(1, -1))[:, 0]
#                     track_uri                              track_name  \
# 34327  3QzAOrNlsabgbMwlZt7TAY              Ballin' (with Roddy Ricch)
# 2072   4pLwZjInHj3SimIyN9SnOz                            Side To Side
# 13112  5bjWdBx64POBYiUny759hy                          Last Christmas
# 1600   4r4V1wYecTxSAAXV11cFPD                                   Focus
# 10164  06EL94D0TA27Ik0Ke5usbj                                 The Way
# 30117  41XCLKG0xl01mGprBDtTNS                              Santa Baby
# 365    7fYbFYt7X4FZvuJJC90EX0                                 Problem
# 8964   3FiE2d325mIOc4YjkSLVJR                                Everyday
# 3043   7hCNBVRhHzcsRAv0TQnOzq                            Runaway Baby
# 19522  2qyhy9ndo8tTGMzXeHTisR                                 So High
# 4680   386RUes7n1uM1yfzgeUuwp                           The Lazy Song
# 9857   1I6pKIyaBp4OebTGLJpCCC                                    Perm
# 16439  1xCqIXCApBgcjwRLostpKl                                   Piano
# 21566  1KtU0WCq472KzqCXgMOxkS  That's What I Like - Alan Walker Remix
# 2611   1X2Zd5wKGbY1oKzb8dzJRy                              Break Free
# 1060   7yHEDfrJNd0zWOfXwydNH0                                Into You
# 937    5g7sDjBhZ4I3gcFIpkrLuI                    Locked Out Of Heaven
# 10160  3tRFqxTYOjeTmCiVaGDCsq                              Be Alright
# 2998   2h1IPjP471JJRSShTHRUhi                         Dangerous Woman
# 4842   6b8Be6ljOzmkOmFslEb23P                               24K Magic
#
#          artist_name            album_name  duration_ms  danceability  energy  \
# 34327        Mustard           Perfect Ten       180434         0.809   0.545
# 2072   Ariana Grande       Dangerous Woman       226160         0.648   0.738
# 13112  Ariana Grande      Christmas Kisses       203653         0.677   0.791
# 1600   Ariana Grande       Dangerous Woman       211360         0.672   0.876
# 10164  Ariana Grande           Yours Truly       227026         0.645   0.877
# 30117  Ariana Grande      Christmas Kisses       170933         0.722   0.778
# 365    Ariana Grande         My Everything       193893         0.654   0.797
